# %%
import pandas as pd
import numpy as np
import configparser as cp
from plotnine import *
import mysql.connector
from sqlalchemy import create_engine

# %%
## db connection
config=cp.ConfigParser()
config.read('/home/ubuntu/certi/db_login.txt')
db_config=config['ivan_db']


## 2. db connection
engine=create_engine('mysql+mysqlconnector://{0:s}:{1:s}@{2:s}/{3:s}'.format(db_config['userid'],
                                                                             db_config['pwd'],
                                                                             db_config['hostname'],
                                                                             db_config['schema']
                                                                            ))
engine
# Out:
# Engine(mysql+mysqlconnector://ilong:***@ivandb.cnwzhaenwyah.us-east-2.rds.amazonaws.com:3306/covid19)

# %% [markdown]
# # Data Loading

# %% [markdown]
# ### Stock Prices

# %%
## stock_price
df_stock_price=pd.read_sql("""SELECT *
                              FROM STOCK_PRED.ALL_STOCK_HIST
                              WHERE DATE>=STR_TO_DATE('2012-01-01','%Y-%m-%d')
                              AND STOCK IN ('NVDA','CRM','MSFT','UNH','GS','HD','V','DIS','BA','DASH') """, con=engine)
print(df_stock_price.shape)
print(df_stock_price.Stock.nunique())
print(df_stock_price['Date'].min(),df_stock_price['Date'].max())
df_stock_price.info()
# Out:
# (22694, 9)
# 10
# 2012-01-03 00:00:00 2021-11-30 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22694 entries, 0 to 22693
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          22694 non-null  datetime64[ns]
#  1   Open          22694 non-null  float64
#  2   High          22694 non-null  float64
#  3   Low           22694 non-null  float64
#  4   Close         22694 non-null  float64
#  5   Volume        22694 non-null  float64
#  6   SE            22694 non-null  object
#  7   Stock         22694 non-null  object
#  8   REFRESH_DATE  22694 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(5), object(2)
# memory usage: 1.6+ MB

# %%
df_stock_price.sort_values(by='Date',ascending=False).head(5)
# Out:
#             Date        Open        High         Low       Close      Volume  \
# 22403 2021-11-22  200.000000  201.699997  194.600006  195.580002  21185800.0
# 22396 2021-11-22  442.820007  443.750000  437.390015  437.540009   2598700.0
# 22375 2021-11-22  153.229996  155.820007  152.570007  154.160004  12770900.0
# 22389 2021-11-22  409.799988  416.559998  408.700012  408.790009   4006400.0
# 22368 2021-11-22  301.839996  305.489990  296.720001  296.839996   4474700.0
#
#          SE Stock        REFRESH_DATE
# 22403  NYSE     V 2021-11-23 07:10:33
# 22396  NYSE   UNH 2021-11-23 07:10:33
# 22375  NYSE   DIS 2021-11-23 07:10:33
# 22389  NYSE    HD 2021-11-23 07:10:33
# 22368  NYSE   CRM 2021-11-23 07:10:33

# %%
df_stock_price.groupby(['Stock']).agg(num_records=('Date','size'),
                                      min_date=('Date','min'),
                                      max_date=('Date','max'),
                                      min_price=('Close','min'),
                                      max_price=('Close','max')
                                     ).reset_index(drop=False)
# Out:
#   Stock  num_records   min_date   max_date   min_price   max_price
# 0    BA         2491 2012-01-03 2021-11-24   55.241615  430.299988
# 1   CRM         2492 2012-01-03 2021-11-24   24.370001  309.959991
# 2  DASH          242 2020-12-09 2021-11-24  112.989998  245.970001
# 3   DIS         2492 2012-01-03 2021-11-24   34.300621  201.910004
# 4    GS         2492 2012-01-03 2021-11-24   79.032585  423.850006
# 5    HD         2491 2012-01-03 2021-11-24   34.111156  412.109985
# 6  MSFT         2491 2012-01-03 2021-11-24   21.749044  343.109985
# 7  NVDA         2491 2012-01-03 2021-11-24    2.614228  329.850006
# 8   UNH         2491 2012-01-03 2021-11-29   43.194290  464.350006
# 9     V         2493 2012-01-03 2021-11-29   23.094339  250.588379

# %% [markdown]
# ### Stock Recommendations

# %%
df_stock_recom=pd.read_sql("""SELECT *
                              FROM STOCK_PRED.STOCK_RECOMMENDS
                              WHERE STOCK IN ('NVDA','CRM','MSFT','UNH','GS','HD','V','DIS','BA','DASH') """, con=engine)
df_stock_recom.columns=df_stock_recom.columns.str.replace(' ','_')
print(df_stock_recom.shape)
print(df_stock_recom.Stock.nunique())
df_stock_recom.info()
# Out:
# (2560, 7)
# 10
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2560 entries, 0 to 2559
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2560 non-null   datetime64[ns]
#  1   Firm          2560 non-null   object
#  2   To_Grade      2560 non-null   object
#  3   From_Grade    2560 non-null   object
#  4   Action        2560 non-null   object
#  5   Stock         2560 non-null   object
#  6   REFRESH_DATE  2560 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(5)
# memory usage: 140.1+ KB

# %%
## review
df_stock_recom
# Out:
#                     Date               Firm    To_Grade From_Grade Action  \
# 0    2012-01-18 00:00:00   Societe Generale        Sell              down
# 1    2012-04-11 00:00:00      Deutsche Bank         Buy              main
# 2    2012-04-25 00:00:00        DA Davidson     Neutral              main
# 3    2012-04-26 00:00:00     Morgan Stanley  Overweight              main
# 4    2012-05-21 00:00:00     Argus Research         Buy                up
# ...                  ...                ...         ...        ...    ...
# 2510 2021-09-17 10:57:24  B of A Securities         Buy              main
# 2511 2021-09-28 11:15:04        Susquehanna    Positive              main
# 2512 2021-10-05 08:36:41            Keybanc  Overweight              main
# 2513 2021-11-04 14:41:41        Wells Fargo  Overweight              main
# 2514 2021-11-10 15:07:02  B of A Securities         Buy              main
#
#      Stock        REFRESH_DATE
# 0       BA 2021-11-16 09:51:15
# 1       BA 2021-11-16 09:51:15
# 2       BA 2021-11-16 09:51:15
# 3       BA 2021-11-16 09:51:15
# 4       BA 2021-11-16 09:51:15
# ...    ...                 ...
# 2510  NVDA 2021-11-16 09:51:15
# 2511  NVDA 2021-11-16 09:51:15
# 2512  NVDA 2021-11-16 09:51:15
# 2513  NVDA 2021-11-16 09:51:15
# 2514  NVDA 2021-11-16 09:51:15
#
# [2515 rows x 7 columns]

# %%
## agg
df_stock_recom.groupby(['Stock']).agg(num_records=('Date','size'),
                                      dist_firms=('Firm','nunique'),
                                      min_date=('Date','min'),
                                      max_date=('Date','max')
                                     ).reset_index(drop=False)
# Out:
#   Stock  num_records  dist_firms            min_date            max_date
# 0    BA          218          43 2012-01-18 00:00:00 2021-10-28 00:00:00
# 1   CRM          344          77 2012-02-24 09:00:00 2021-11-02 09:32:19
# 2   DIS          285          58 2012-02-08 08:43:00 2021-10-18 09:23:22
# 3    GS          212          47 2012-03-16 06:15:00 2021-10-25 12:14:25
# 4    HD          239          50 2012-02-22 09:06:00 2021-11-09 14:21:06
# 5  MSFT          358          58 2012-03-16 08:19:00 2021-11-02 09:45:19
# 6  NVDA          383          65 2012-02-13 07:27:00 2021-11-10 15:07:02
# 7   UNH          202          38 2012-03-19 09:40:00 2021-11-10 13:04:51
# 8     V          274          55 2012-02-08 08:05:00 2021-11-01 14:01:38

# %%
## To_Grade
df_stock_recom.To_Grade.value_counts()
# Overweight: A stock is rated an Overweight stock by analysts when they discover factors that augur good price performance over the next six to 12 months. The Overweight rating is given when the analyst thinks the stock will outperform other stocks in its market sector or those in a market index like the Standard and Poor's 500
# Outperform: a stock is expected to do slightly better than the market return.
# Market outperform: one that is expected to outperform a specific index or the overall market. It is considered to be a better ranking than market perform and one step less than a strong buy rating

# Buy: Also known as strong buy and "on the recommended list." Needless to say, buy is a recommendation to purchase a specific security.
# Sell: Also known as strong sell, it's a recommendation to sell a security or to liquidate an asset.
# Hold: In general terms, a company with a hold recommendation is expected to perform at the same pace as comparable companies or in line with the market.
# Underperform: A recommendation that means a stock is expected to do slightly worse than the overall stock market return. Underperform can also be expressed as "moderate sell," "weak hold," and "underweight."
# Outperform: Also known as "moderate buy," "accumulate," and "overweight." Outperform is an analyst recommendation meaning a stock is expected to do slightly better than the market return.

# Market Outperform a stock is expected to do better than the market return

# %%
grade_map={'Buy':2,
           'Outperform':1, # a stock is expected to do slightly better than the market return.
           'Overweight':1, # A stock is rated an Overweight stock by analysts when they discover factors that augur good price performance over the next six to 12 months. The Overweight rating is given when the analyst thinks the stock will outperform other stocks in its market sector or those in a market index like the Standard and Poor's 500
           'Neutral':0,
           'Hold':0,
           'Market Perform':0, # stock will provide returns that are the same as a specific index such as the S&P 500 or another leading market average. 
           'Equal-Weight':0, # rating suggests that a stock will perform in line with the average of all the stocks that analyst may cover
           'Sell':-3,
           'Underperform':-1,
           'Strong Buy':3,
           'Underweight':-1, # expected to be below the average total return of the analyst's industry
           'Market Outperform':2, # one that is expected to outperform a specific index or the overall market. It is considered to be a better ranking than market perform and one step less than a strong buy rating
           'Positive':1,
           'In-Line':0, # A situation or announcement that meets or nears the expectations of most analysts
           'Sector Perform':0,
           'Perform':0,
           'Reduce':-2,
           'Long-Term Buy':2,
           'Sector Weight':0,
           'Equal-weight':0,
           'Top Pick':3,
           'Peer Perform':0,
           'Mixed':0,
           'Negative':-2,
           'Hold Neutral':0,
           'Accumulate':1, # traders and investors are willing to buy the asset in mass. ... In this sense, accumulation refers to buyers that are more aggressive than sellers, which pushes the price up
           'Average':0  
          }
df_stock_recom.loc[:,'Grade_Score']=df_stock_recom.To_Grade.map(grade_map)
df_stock_recom.groupby(['To_Grade','Grade_Score']).agg(num_records=('To_Grade','size'))
# Out:
#                                num_records
# To_Grade          Grade_Score
# Accumulate         1.0                   1
# Average            0.0                   1
# Buy                2.0                 831
# Equal-Weight       0.0                  67
# Equal-weight       0.0                   3
# Hold               0.0                 188
# Hold Neutral       0.0                   1
# In-Line            0.0                  13
# Long-Term Buy      2.0                   4
# Market Outperform  2.0                  19
# Market Perform     0.0                  64
# Mixed              0.0                   1
# Negative          -2.0                   1
# Neutral            0.0                 274
# Outperform         1.0                 469
# Overweight         1.0                 454
# Peer Perform       0.0                   2
# Perform            0.0                   5
# Positive           1.0                  18
# Reduce            -2.0                   4
# Sector Perform     0.0                  13
# Sector Weight      0.0                   4
# Sell              -3.0                  36
# Strong Buy         3.0                  32
# Top Pick           3.0                   2
# Underperform      -1.0                  32
# Underweight       -1.0                  19

# %% [markdown]
# # 01 Analysis - Spot check recommendations
# * Monthly overall recommendations aggregated
# * Firm recommendations comparision

# %% [markdown]
# ## Data Checking - MSFT

# %% [markdown]
# ### Stock Prices

# %%
## Stock Price
msft_stock_price=df_stock_price.loc[df_stock_price.Stock=='MSFT',:]
print(
    ggplot(aes('Date','Close'),msft_stock_price)
    +geom_line(color='blue',alpha=0.4)
    +scale_x_datetime(date_breaks='2 month',date_labels='%Y-%m')
    +scale_y_continuous(breaks=np.arange(msft_stock_price.Close.max()+20,20))
    +theme(axis_text_x=element_text(angle=90),figure_size=(16,8))
    +labs(title='MSFT stock price')

)
# Out:
# <ggplot: (8742708702677)>

# %% [markdown]
# ### Recommnedations

# %%
## Recommendations
msft_recom=df_stock_recom.loc[df_stock_recom.Stock=='MSFT',:].reset_index(drop=True)
msft_recom.loc[:,'Date_si']=msft_recom['Date'].dt.normalize()
msft_recom.loc[:,'Date_mnth']=[x.replace(day=1) for x in msft_recom['Date'].dt.normalize()]
msft_recom.loc[:,'Date_yr']=msft_recom.Date.dt.year
print(msft_recom.shape,msft_recom['Date'].min(),msft_recom['Date'].max())
# Out:
# (358, 11) 2012-03-16 08:19:00 2021-11-02 09:45:19

# %%
msft_recom.loc[:20]
# Out:
#                   Date                  Firm        To_Grade  From_Grade  \
# 0  2012-03-16 08:19:00        Argus Research             Buy
# 1  2012-03-19 14:00:00        Hilliard Lyons   Long-Term Buy
# 2  2012-03-22 07:03:00        Morgan Stanley      Overweight
# 3  2012-04-03 11:53:00                   UBS             Buy
# 4  2012-04-20 06:18:00         Deutsche Bank             Buy
# 5  2012-04-20 06:44:00         Goldman Sachs         Neutral
# 6  2012-04-20 07:05:00          Bank oferica             Buy
# 7  2012-04-20 11:51:00                   UBS             Buy
# 8  2012-04-20 12:28:00  McAdams Wright Ragen             Buy
# 9  2012-07-20 06:43:00         Goldman Sachs         Neutral
# 10 2012-07-20 08:24:00    Griffin Securities             Buy
# 11 2012-08-20 09:14:00      Longbow Research             Buy
# 12 2012-09-12 16:01:00             Jefferies            Hold
# 13 2012-10-01 09:11:00           RBC Capital  Sector Perform  Outperform
# 14 2012-10-01 09:33:00           RBC Capital  Sector Perform  Outperform
# 15 2012-10-19 12:10:00              Barclays    Equal-Weight
# 16 2012-11-28 07:50:00                Nomura
# 17 2012-12-05 14:00:34          MKM Partners         Neutral
# 18 2012-12-12 09:17:13   Standpoint Research             Buy        Hold
# 19 2012-12-13 12:17:44              Barclays    Equal-Weight
# 20 2012-12-14 07:53:50           BMO Capital  Market Perform
#
#    Action Stock        REFRESH_DATE  Grade_Score    Date_si  Date_mnth  \
# 0      up  MSFT 2021-11-16 09:51:15          2.0 2012-03-16 2012-03-01
# 1    main  MSFT 2021-11-16 09:51:15          2.0 2012-03-19 2012-03-01
# 2    main  MSFT 2021-11-16 09:51:15          1.0 2012-03-22 2012-03-01
# 3    main  MSFT 2021-11-16 09:51:15          2.0 2012-04-03 2012-04-01
# 4    main  MSFT 2021-11-16 09:51:15          2.0 2012-04-20 2012-04-01
# 5    main  MSFT 2021-11-16 09:51:15          0.0 2012-04-20 2012-04-01
# 6    main  MSFT 2021-11-16 09:51:15          2.0 2012-04-20 2012-04-01
# 7    main  MSFT 2021-11-16 09:51:15          2.0 2012-04-20 2012-04-01
# 8    main  MSFT 2021-11-16 09:51:15          2.0 2012-04-20 2012-04-01
# 9    main  MSFT 2021-11-16 09:51:15          0.0 2012-07-20 2012-07-01
# 10   init  MSFT 2021-11-16 09:51:15          2.0 2012-07-20 2012-07-01
# 11   init  MSFT 2021-11-16 09:51:15          2.0 2012-08-20 2012-08-01
# 12   init  MSFT 2021-11-16 09:51:15          0.0 2012-09-12 2012-09-01
# 13   down  MSFT 2021-11-16 09:51:15          0.0 2012-10-01 2012-10-01
# 14   down  MSFT 2021-11-16 09:51:15          0.0 2012-10-01 2012-10-01
# 15   main  MSFT 2021-11-16 09:51:15          0.0 2012-10-19 2012-10-01
# 16   main  MSFT 2021-11-16 09:51:15          NaN 2012-11-28 2012-11-01
# 17   main  MSFT 2021-11-16 09:51:15          0.0 2012-12-05 2012-12-01
# 18     up  MSFT 2021-11-16 09:51:15          2.0 2012-12-12 2012-12-01
# 19   main  MSFT 2021-11-16 09:51:15          0.0 2012-12-13 2012-12-01
# 20   init  MSFT 2021-11-16 09:51:15          0.0 2012-12-14 2012-12-01
#
#     Date_yr
# 0      2012
# 1      2012
# 2      2012
# 3      2012
# 4      2012
# 5      2012
# 6      2012
# 7      2012
# 8      2012
# 9      2012
# 10     2012
# 11     2012
# 12     2012
# 13     2012
# 14     2012
# 15     2012
# 16     2012
# 17     2012
# 18     2012
# 19     2012
# 20     2012

# %%
msft_recom.loc[msft_recom.Firm=='Argus Research',:]
# Out:
#                    Date            Firm To_Grade From_Grade Action Stock  \
# 0   2012-03-16 08:19:00  Argus Research      Buy                up  MSFT
# 277 2020-06-24 13:30:12  Argus Research      Buy              main  MSFT
# 311 2021-01-28 18:11:05  Argus Research      Buy              main  MSFT
# 316 2021-04-13 14:58:26  Argus Research      Buy              main  MSFT
#
#            REFRESH_DATE  Grade_Score     Date_si  Date_mnth  Date_yr
# 0   2021-11-16 09:51:15          2.0  2012-03-16 2012-03-01     2012
# 277 2021-11-16 09:51:15          2.0  2020-06-24 2020-06-01     2020
# 311 2021-11-16 09:51:15          2.0  2021-01-28 2021-01-01     2021
# 316 2021-11-16 09:51:15          2.0  2021-04-13 2021-04-01     2021

# %%
## 
print(
    ggplot(aes('Date_mnth','num_firms',fill='Date_yr',group='Date_yr'),
           msft_recom.groupby(['Date_yr','Date_mnth']).agg(num_firms=('Firm','nunique')).reset_index(drop=False)
          )
    +geom_col()
    +theme(axis_text_x=element_text(angle=90))

)
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8736807310661)>

# %%
msft_recom.loc[msft_recom.Date_mnth==pd.to_datetime('2021-10-01',format='%Y-%m-%d'),:]
# Out:
#                    Date            Firm    To_Grade From_Grade Action Stock  \
# 347 2021-10-20 14:25:33       Jefferies         Buy              main  MSFT
# 348 2021-10-20 14:30:31         Wedbush  Outperform              main  MSFT
# 349 2021-10-25 08:44:47         Keybanc  Overweight              main  MSFT
# 350 2021-10-27 08:54:20   Piper Sandler  Overweight              main  MSFT
# 351 2021-10-27 12:18:42          Stifel         Buy              main  MSFT
# 352 2021-10-27 12:30:28   Goldman Sachs         Buy              main  MSFT
# 353 2021-10-27 12:37:42   Credit Suisse  Outperform              main  MSFT
# 354 2021-10-27 13:41:53        Barclays  Overweight              main  MSFT
# 355 2021-10-27 13:56:33  Morgan Stanley  Overweight              main  MSFT
# 356 2021-10-28 14:55:44       Citigroup         Buy              main  MSFT
#
#            REFRESH_DATE  Grade_Score     Date_si  Date_mnth  Date_yr
# 347 2021-11-16 09:51:15          2.0  2021-10-20 2021-10-01     2021
# 348 2021-11-16 09:51:15          1.0  2021-10-20 2021-10-01     2021
# 349 2021-11-16 09:51:15          1.0  2021-10-25 2021-10-01     2021
# 350 2021-11-16 09:51:15          1.0  2021-10-27 2021-10-01     2021
# 351 2021-11-16 09:51:15          2.0  2021-10-27 2021-10-01     2021
# 352 2021-11-16 09:51:15          2.0  2021-10-27 2021-10-01     2021
# 353 2021-11-16 09:51:15          1.0  2021-10-27 2021-10-01     2021
# 354 2021-11-16 09:51:15          1.0  2021-10-27 2021-10-01     2021
# 355 2021-11-16 09:51:15          1.0  2021-10-27 2021-10-01     2021
# 356 2021-11-16 09:51:15          2.0  2021-10-28 2021-10-01     2021

# %% [markdown]
# ### Data Restructuring

# %%
## Consider doing this with SQL
msft_recom_re=msft_recom.groupby(['Date_mnth']).apply(lambda x: pd.Series({'min_recomms_date':x.Date_si.min(),
                                                                           'num_recomms':x.Grade_Score.size,
                                                                           'num_firms':x.Firm.nunique(),
                                                                           'pos_recomms':(x.Grade_Score>0).astype(float).sum(),
                                                                           'neg_recomms':(x.Grade_Score<0).astype(float).sum(),
                                                                           'grade_average':x.Grade_Score.mean(),
                                                                           'pos_recomms_perc':(x.Grade_Score>0).mean()
                                                                          })).reset_index(drop=False)

#msft_recom_re.loc[:,'min_recomms_date']=pd.to_datetime(msft_recom_re.min_recomms_date,format='%Y-%m-%d')
msft_recom_re.loc[:,'grade_cat']='neutral'
msft_recom_re.loc[msft_recom_re.grade_average>=1,'grade_cat']='Buy'
msft_recom_re.loc[msft_recom_re.grade_average<=-0.5,'grade_cat']='Sell'
print(msft_recom_re.shape)
msft_recom_re.tail(5)
# Out:
# (94, 9)
#     Date_mnth min_recomms_date  num_recomms  num_firms  pos_recomms  \
# 89 2021-07-01       2021-07-16           13          9         13.0
# 90 2021-08-01       2021-08-20            1          1          1.0
# 91 2021-09-01       2021-09-14            2          2          2.0
# 92 2021-10-01       2021-10-20           10         10         10.0
# 93 2021-11-01       2021-11-02            1          1          1.0
#
#     neg_recomms  grade_average  pos_recomms_perc grade_cat
# 89          0.0       1.538462               1.0       Buy
# 90          0.0       1.000000               1.0       Buy
# 91          0.0       1.000000               1.0       Buy
# 92          0.0       1.400000               1.0       Buy
# 93          0.0       2.000000               1.0       Buy

# %% [markdown]
# #### Merging stock price with stock recommendations

# %%
## Viz
msft_stock_price_w_recoms=pd.merge(msft_stock_price,
                                   msft_recom_re,
                                   how='left',
                                   left_on='Date',
                                   right_on='min_recomms_date'
                                  )
print(msft_stock_price_w_recoms.shape,msft_stock_price.shape)

# %%
## Viz
print(
    ggplot(aes('Date','Close'),msft_stock_price_w_recoms)
    +geom_line(color='blue',alpha=0.4)
    +scale_x_datetime(date_breaks='2 month',date_labels='%Y-%m')
    +scale_y_continuous(breaks=np.arange(msft_stock_price.Close.max()+20,20))
    +theme(axis_text_x=element_text(angle=90),figure_size=(16,8))
    +labs(title='MSFT stock price')
    +geom_vline(aes(xintercept='min_recomms_date',color='grade_cat'),
                msft_stock_price_w_recoms.loc[msft_stock_price_w_recoms.num_firms>=3,:] # more than 3 recommendations
               )

)
# Out:
# (2491, 18) (2491, 9)
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8742708484029)>

# %%
## Buy-01 Review predictions before drop in Dec.2018 -> failed to predict the drop
msft_recom.loc[(msft_recom.Date_si>=pd.to_datetime('2018-10-01',format='%Y-%m-%d'))&
               (msft_recom.Date_si<=pd.to_datetime('2018-12-01',format='%Y-%m-%d'))
               ,:]
# Out:
#                    Date       Firm    To_Grade  From_Grade Action Stock  \
# 196 2018-10-12 12:15:23  Macquarie  Outperform     Neutral     up  MSFT
# 197 2018-10-19 14:16:46    Wedbush  Outperform               init  MSFT
# 198 2018-10-25 13:38:56    KeyBanc  Overweight  Overweight   main  MSFT
# 199 2018-10-25 14:38:46     Nomura         Buy         Buy   main  MSFT
# 200 2018-10-25 14:59:09  Citigroup     Neutral     Neutral   main  MSFT
#
#            REFRESH_DATE  Grade_Score    Date_si  Date_mnth  Date_yr
# 196 2021-11-16 09:51:15          1.0 2018-10-12 2018-10-01     2018
# 197 2021-11-16 09:51:15          1.0 2018-10-19 2018-10-01     2018
# 198 2021-11-16 09:51:15          1.0 2018-10-25 2018-10-01     2018
# 199 2021-11-16 09:51:15          2.0 2018-10-25 2018-10-01     2018
# 200 2021-11-16 09:51:15          0.0 2018-10-25 2018-10-01     2018

# %%
## Buy-02 Review predictions before drop in Feb.2020 -> failed to predict the drop
msft_recom.loc[(msft_recom.Date_si>=pd.to_datetime('2019-12-01',format='%Y-%m-%d'))&
               (msft_recom.Date_si<=pd.to_datetime('2020-05-01',format='%Y-%m-%d'))
# 274 2021-11-16 09:51:15          1.0 2020-04-30 2020-04-01     2020
# 275 2021-11-16 09:51:15          1.0 2020-04-30 2020-04-01     2020

# %%
## Sell-01: July, 2015 -> failed
msft_recom.loc[(msft_recom.Date_si>=pd.to_datetime('2015-06-01',format='%Y-%m-%d'))&
               (msft_recom.Date_si<=pd.to_datetime('2015-08-01',format='%Y-%m-%d'))
               ,:]
# Out:
#                    Date            Firm      To_Grade From_Grade Action Stock  \
# 103 2015-06-03 09:00:00        Barclays    Overweight              main  MSFT
# 104 2015-06-09 07:24:50      Wunderlich          Hold              init  MSFT
# 105 2015-06-18 07:19:07       Jefferies  Underperform              main  MSFT
# 106 2015-07-08 04:03:18  Morgan Stanley  Equal-Weight              main  MSFT
# 107 2015-07-09 11:00:00       Jefferies  Underperform              main  MSFT
# 108 2015-07-22 07:25:56       Citigroup          Sell              main  MSFT
# 109 2015-07-22 11:00:00        Barclays    Overweight              main  MSFT
#
#            REFRESH_DATE  Grade_Score    Date_si  Date_mnth  Date_yr
# 103 2021-11-16 09:51:15          1.0 2015-06-03 2015-06-01     2015
# 104 2021-11-16 09:51:15          0.0 2015-06-09 2015-06-01     2015
# 105 2021-11-16 09:51:15         -1.0 2015-06-18 2015-06-01     2015
# 106 2021-11-16 09:51:15          0.0 2015-07-08 2015-07-01     2015
# 107 2021-11-16 09:51:15         -1.0 2015-07-09 2015-07-01     2015
# 108 2021-11-16 09:51:15         -3.0 2015-07-22 2015-07-01     2015
# 109 2021-11-16 09:51:15          1.0 2015-07-22 2015-07-01     2015

# %%
## Sell-02: July, 2016 -> failed
msft_recom.loc[(msft_recom.Date_si>=pd.to_datetime('2016-06-01',format='%Y-%m-%d'))&
               (msft_recom.Date_si<=pd.to_datetime('2016-08-01',format='%Y-%m-%d'))
               ,:]
# Out:
#                    Date           Firm        To_Grade From_Grade Action  \
# 137 2016-07-07 12:43:04      Citigroup            Sell              main
# 138 2016-07-19 08:11:03  William Blair  Market Perform              init
# 139 2016-07-20 06:43:17     Wunderlich            Hold              main
# 140 2016-07-20 21:20:39      Citigroup            Sell              main
#
#     Stock        REFRESH_DATE  Grade_Score    Date_si  Date_mnth  Date_yr
# 137  MSFT 2021-11-16 09:51:15         -3.0 2016-07-07 2016-07-01     2016
# 138  MSFT 2021-11-16 09:51:15          0.0 2016-07-19 2016-07-01     2016
# 139  MSFT 2021-11-16 09:51:15          0.0 2016-07-20 2016-07-01     2016
# 140  MSFT 2021-11-16 09:51:15         -3.0 2016-07-20 2016-07-01     2016

# %%
msft_recom_re.loc[(msft_recom_re.min_recomms_date>=pd.to_datetime('2016-06-01',format='%Y-%m-%d'))&
                  (msft_recom_re.min_recomms_date<=pd.to_datetime('2016-08-01',format='%Y-%m-%d')),:]
# Out:
#     Date_mnth min_recomms_date  num_recomms  num_firms  pos_recomms  \
# 44 2016-07-01       2016-07-07            4          3          0.0
#
#     neg_recomms  grade_average  pos_recomms_perc grade_cat
# 44          2.0           -1.5               0.0      Sell

# %%
## Neutral
msft_recom.loc[(msft_recom.Date_si>=pd.to_datetime('2017-06-01',format='%Y-%m-%d'))&
               (msft_recom.Date_si<=pd.to_datetime('2017-08-01',format='%Y-%m-%d'))
               ,:]
# Out:
#                    Date                Firm    To_Grade From_Grade Action  \
# 150 2017-06-22 13:59:50  Cleveland Research         Buy              init
# 151 2017-07-17 16:25:29       Credit Suisse  Outperform              main
# 152 2017-07-21 15:51:27       Deutsche Bank         Buy              main
# 153 2017-07-21 17:16:15           Citigroup        Sell              main
#
#     Stock        REFRESH_DATE  Grade_Score    Date_si  Date_mnth  Date_yr
# 150  MSFT 2021-11-16 09:51:15          2.0 2017-06-22 2017-06-01     2017
# 151  MSFT 2021-11-16 09:51:15          1.0 2017-07-17 2017-07-01     2017
# 152  MSFT 2021-11-16 09:51:15          2.0 2017-07-21 2017-07-01     2017
# 153  MSFT 2021-11-16 09:51:15         -3.0 2017-07-21 2017-07-01     2017

# %%
msft_recom_re.loc[(msft_recom_re.min_recomms_date>=pd.to_datetime('2017-06-01',format='%Y-%m-%d'))&
                  (msft_recom_re.min_recomms_date<=pd.to_datetime('2017-08-01',format='%Y-%m-%d')),:]
# Out:
#     Date_mnth min_recomms_date  num_recomms  num_firms  pos_recomms  \
# 51 2017-06-01       2017-06-22            1          1          1.0
# 52 2017-07-01       2017-07-17            3          3          2.0
#
#     neg_recomms  grade_average  pos_recomms_perc grade_cat
# 51          0.0            2.0          1.000000       Buy
# 52          1.0            0.0          0.666667   neutral

# %% [markdown]
# ## Data Checking - Doordash

# %%
dash_stock_price=df_stock_price.loc[df_stock_price.Stock=='DASH',:]
print(dash_stock_price.shape)
print(dash_stock_price['Date'].min(),dash_stock_price['Date'].max())

print(
    ggplot(dash_stock_price,aes('Date','Close'))
    +geom_line(color='blue',alpha=0.5)
    +scale_x_datetime(date_breaks='7 days',date_labels='%Y-%m')
    +scale_y_continuous(breaks=np.arange(0,275,25))
    +theme(axis_text_x=element_text(angle=90),figure_size=(16,8))
    +labs(title='Doordash Stock Price')

)
# Out:
# (245, 9)
# 2020-12-09 00:00:00 2021-11-30 00:00:00
# <ggplot: (8731349621785)>

# %% [markdown]
# ### Data Processing

# %%
## 1. Recommendations
dash_recom=df_stock_recom.loc[df_stock_recom.Stock=='DASH',:].reset_index(drop=True)
print(dash_recom.shape)
print(dash_recom['Date'].min(),dash_recom['Date'].max())

## reformating
dash_recom.loc[:,'Date_si']=dash_recom['Date'].dt.normalize()
dash_recom.loc[:,'Date_mnth']=[x.replace(day=1) for x in dash_recom.Date_si]

dash_recom
# Out:
# (45, 8)
# 2020-12-10 11:54:19 2021-11-10 14:44:35
#                   Date                Firm           To_Grade    From_Grade  \
# 0  2020-12-10 11:54:19                BTIG            Neutral
# 1  2020-12-14 13:45:32         DA Davidson            Neutral           Buy
# 2  2020-12-18 13:56:05         Susquehanna           Positive
# 3  2021-01-04 10:09:01             Needham                Buy
# 4  2021-01-04 10:31:44         RBC Capital     Sector Perform
# 5  2021-01-04 10:37:40           JP Morgan            Neutral
  DASH 2021-11-16 09:51:15          0.0 2021-01-04 2021-01-01
# 15   init  DASH 2021-11-16 09:51:15          0.0 2021-01-15 2021-01-01
# 16   init  DASH 2021-11-16 09:51:15          0.0 2021-01-27 2021-01-01
# 17   main  DASH 2021-11-16 09:51:15          0.0 2021-02-22 2021-02-01
# 18   main  DASH 2021-11-16 09:51:15          0.0 2021-02-26 2021-02-01
# 19   main  DASH 2021-11-16 09:51:15          0.0 2021-03-01 2021-03-01
# 20   init  DASH 2021-11-16 09:51:15          1.0 2021-04-01 2021-04-01
# 21   init  DASH 2021-11-16 09:51:15          0.0 2021-04-06 2021-04-01
# 22   init  DASH 2021-11-16 09:51:15          2.0 2021-04-27 2021-04-01
# 23     up  DASH 2021-11-16 09:51:15          2.0 2021-05-14 2021-05-01
# 24     up  DASH 2021-11-16 09:51:15          1.0 2021-05-14 2021-05-01
# 25   main  DASH 2021-11-16 09:51:15          0.0 2021-05-19 2021-05-01
# 26   main  DASH 2021-11-16 09:51:15          2.0 2021-06-22 2021-06-01
# 27   main  DASH 2021-11-16 09:51:15          1.0 2021-06-29 2021-06-01
# 28   init  DASH 2021-11-16 09:51:15          2.0 2021-08-02 2021-08-01
# 29   main  DASH 2021-11-16 09:51:15          2.0 2021-08-13 2021-08-01
# 30   main  DASH 2021-11-16 09:51:15          2.0 2021-08-13 2021-08-01
# 31   main  DASH 2021-11-16 09:51:15          1.0 2021-08-13 2021-08-01
# 32   main  DASH 2021-11-16 09:51:15          0.0 2021-08-13 2021-08-01
# 33   main  DASH 2021-11-16 09:51:15          1.0 2021-08-13 2021-08-01
# 34   main  DASH 2021-11-16 09:51:15          1.0 2021-08-17 2021-08-01
# 35   init  DASH 2021-11-16 09:51:15          0.0 2021-09-13 2021-09-01
# 36     up  DASH 2021-11-16 09:51:15          2.0 2021-09-16 2021-09-01
# 37   main  DASH 2021-11-16 09:51:15          2.0 2021-10-01 2021-10-01
# 38   main  DASH 2021-11-16 09:51:15          2.0 2021-10-06 2021-10-01
# 39   main  DASH 2021-11-16 09:51:15          2.0 2021-10-18 2021-10-01
# 40   down  DASH 2021-11-16 09:51:15          0.0 2021-11-10 2021-11-01
# 41   main  DASH 2021-11-16 09:51:15          2.0 2021-11-10 2021-11-01
# 42   main  DASH 2021-11-16 09:51:15          0.0 2021-11-10 2021-11-01
# 43   main  DASH 2021-11-16 09:51:15          1.0 2021-11-10 2021-11-01
# 44   main  DASH 2021-11-16 09:51:15          0.0 2021-11-10 2021-11-01

# %%
dash_recom.dtypes
# Out:
# Date            datetime64[ns]
# Firm                    object
# To_Grade                object
# From_Grade              object
# Action                  object
# Stock                   object
# REFRESH_DATE    datetime64[ns]
# Grade_Score            float64
# Date_si         datetime64[ns]
# Date_mnth       datetime64[ns]
# dtype: object

# %%
## 2. Recommendation Aggregate
dash_recom_re=dash_recom.groupby(['Date_mnth']).apply(lambda x:pd.Series({'min_recomms_date':x.Date_si.min(),
                                                                          'num_records':x.Grade_Score.size,
                                                                          'num_firms':x.Firm.nunique(),
                                                                          'pos_recoms':(x.Grade_Score>0).astype(float).sum(),
                                                                          'neg_recoms':(x.Grade_Score<0).astype(float).sum(),
                                                                          'grade_average':x.Grade_Score.mean()
                                                                         })).reset_index(drop=False)
dash_recom_re.loc[:,'grade_cat']='Neutral'
dash_recom_re.loc[dash_recom_re.grade_average>=1,'grade_cat']='Buy'
dash_recom_re.loc[dash_recom_re.grade_average<=-0.5,'grade_cat']='Sell'

dash_recom_re.loc[dash_recom_re.min_recomms_date==pd.to_datetime('2021-08-02',format='%Y-%m-%d'),'min_recomms_date']=pd.to_datetime('2021-08-03',format='%Y-%m-%d')

print(dash_recom_re.grade_cat.value_counts())
print(dash_recom_re.loc[~dash_recom_re.min_recomms_date.isin(dash_stock_price['Date']),:].shape)
print(dash_recom_re.num_firms.describe())
dash_recom_re
# Out:
# Buy        6
# Neutral    5
# Name: grade_cat, dtype: int64
# (0, 8)
# count    11.000000
# mean      4.090909
# std       3.672997
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max      14.000000
# Name: num_firms, dtype: float64
#     Date_mnth min_recomms_date  num_records  num_firms  pos_recoms  \
# 0  2020-12-01       2020-12-10            3          3         1.0
# 1  2021-01-01       2021-01-04           14         14         4.0
# 2  2021-02-01       2021-02-22            2          2         0.0
# 3  2021-03-01       2021-03-01            1          1         0.0
# 4  2021-04-01       2021-04-01            3          3         2.0
# 5  2021-05-01       2021-05-14            3          3         2.0
# 6  2021-06-01       2021-06-22            2          2         2.0
# 7  2021-08-01       2021-08-03            7          7         6.0
# 8  2021-09-01       2021-09-13            2          2         1.0
# 9  2021-10-01       2021-10-01            3          3         3.0
# 10 2021-11-01       2021-11-10            5          5         2.0
#
#     neg_recoms  grade_average grade_cat
# 0          0.0       0.333333   Neutral
# 1          0.0       0.500000   Neutral
# 2          0.0       0.000000   Neutral
# 3          0.0       0.000000   Neutral
# 4          0.0       1.000000       Buy
# 5          0.0       1.000000       Buy
# 6          0.0       1.500000       Buy
# 7          0.0       1.285714       Buy
# 8          0.0       1.000000       Buy
# 9          0.0       2.000000       Buy
# 10         0.0       0.600000   Neutral

# %%
## 3. Merging with stock prices
dash_stock_price_w_recom=pd.merge(dash_stock_price,
                                  dash_recom_re,
                                  how='left',
                                  left_on='Date',
                                  right_on='min_recomms_date'
                                 )
print(dash_stock_price.shape)
print(dash_stock_price_w_recom.shape)
dash_stock_price_w_recom
# Out:
# (245, 9)
# (245, 17)
#           Date        Open        High         Low       Close      Volume  \
# 0   2020-12-09  182.000000  195.500000  163.800003  189.509995  25373700.0
# 1   2020-12-10  179.710007  187.695007  172.636002  186.000000   9307600.0
# 2   2020-12-11  176.520004  182.000000  168.250000  175.000000   4760600.0
# 3   2020-12-14  169.100006  170.000000  151.199997  160.000000   7855000.0
# 4   2020-12-15  157.100006  161.419998  153.759995  158.889999   5017000.0
# ..         ...         ...         ...         ...         ...         ...
# 240 2021-11-23  193.809998  199.360001  182.809998  184.309998   4969800.0
# 241 2021-11-24  181.100006  189.970001  177.649994  184.929993   4357700.0
# 242 2021-11-26  187.899994  189.000000  181.360001  187.919998   3231400.0
# 243 2021-11-29  186.550003  188.970001  178.130005  183.009995   4794100.0
# 244 2021-11-30  226.440002  229.619995  223.835007  178.770004   6190750.0
#
#        SE Stock        REFRESH_DATE  Date_mnth min_recomms_date  num_records  \
# 0    NYSE  DASH 2021-08-15 00:00:00        NaT              NaT          NaN
# 1    NYSE  DASH 2021-08-15 00:00:00 2020-12-01       2020-12-10          3.0
# 2    NYSE  DASH 2021-08-15 00:00:00        NaT              NaT          NaN
# 3    NYSE  DASH 2021-08-15 00:00:00        NaT              NaT          NaN
# 4    NYSE  DASH 2021-08-15 00:00:00        NaT              NaT          NaN
# ..    ...   ...                 ...        ...              ...          ...
# 240  NYSE  DASH 2021-11-25 02:58:01        NaT              NaT          NaN
# 241  NYSE  DASH 2021-11-26 03:02:48        NaT              NaT          NaN
# 242  NYSE  DASH 2021-12-01 02:57:56        NaT              NaT          NaN
# 243  NYSE  DASH 2021-12-01 02:57:56        NaT              NaT          NaN
# 244  NYSE  DASH 2021-12-01 02:57:56        NaT              NaT          NaN
#
#      num_firms  pos_recoms  neg_recoms  grade_average grade_cat
# 0          NaN         NaN         NaN            NaN       NaN
# 1          3.0         1.0         0.0       0.333333   Neutral
# 2          NaN         NaN         NaN            NaN       NaN
# 3          NaN         NaN         NaN            NaN       NaN
# 4          NaN         NaN         NaN            NaN       NaN
# ..         ...         ...         ...            ...       ...
# 240        NaN         NaN         NaN            NaN       NaN
# 241        NaN         NaN         NaN            NaN       NaN
# 242        NaN         NaN         NaN            NaN       NaN
# 243        NaN         NaN         NaN            NaN       NaN
# 244        NaN         NaN         NaN            NaN       NaN
#
# [245 rows x 17 columns]

# %% [markdown]
# ### Viz - doordash

# %%
print(
    ggplot(aes('Date','Close'),dash_stock_price_w_recom)
    +geom_line(color='blue',alpha=0.5)
    +scale_x_datetime(date_breaks='7 days',date_labels=('%Y-%m'))
    +theme(axis_text_x=element_text(angle=90),figure_size=(16,8))
    +labs(title='Doordash Stock Prices')
    +geom_vline(aes(xintercept='min_recomms_date',color='grade_cat',size='num_firms'))

)
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/mizani/bounds.py:352: RuntimeWarning: invalid value encountered in less
#   outside = (x < range[0]) | (x > range[1])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/mizani/bounds.py:352: RuntimeWarning: invalid value encountered in greater
#   outside = (x < range[0]) | (x > range[1])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/plotnine/layer.py:452: PlotnineWarning: geom_vline : Removed 234 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (8731339067457)>

# %%
## Validation - neutral
dash_recom.loc[dash_recom.Date_mnth.isin([pd.to_datetime('2020-12-01',format='%Y-%m-%d'), # valid next month
                                          pd.to_datetime('2021-01-01',format='%Y-%m-%d'), # only vaild if we look at this for more than 2 months
                                          pd.to_datetime('2021-02-01',format='%Y-%m-%d'), # valid next two months
                                          pd.to_datetime('2021-11-01',format='%Y-%m-%d')  # valid next two months
                                         
                                         ])]
# Out:
#                   Date               Firm           To_Grade From_Grade  \
