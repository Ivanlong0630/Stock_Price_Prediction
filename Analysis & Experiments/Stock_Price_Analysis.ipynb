# %%
import pandas as pd
import numpy as np
import joblib
import os
import configparser as cp
from sqlalchemy import create_engine
import mysql.connector
import datetime

from plotnine import *
os.getcwd()
# Out:
# '/home/ubuntu/Python_Projects/Stock_Price_Prediction'

# %%
config=cp.ConfigParser()
config.read('/home/ubuntu/certi/db_login.txt')
db_config=config['ivan_db']
engine=create_engine('mysql+mysqlconnector://{0:s}:{1:s}@{2:s}/{3:s}'.format(db_config['userid'],
                                                                             db_config['pwd'],
                                                                             db_config['hostname'],
                                                                             'STOCK_PRED'))

# %% [markdown]
# # Data Loading

# %% [raw]
# df=pd.read_sql("""SELECT *
#                   FROM STOCK_PRED.ALL_STOCK_HIST
#                   WHERE DATE>=STR_TO_DATE('2020-01-01','%Y-%m-%d')
#                   """,
#               con=engine)
# print(df.shape)
# joblib.dump(df,'/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/stock_price_2020_2021.pkl')

# %% [markdown]
# ### Raw Data

# %%
## Raw Data
df=joblib.load('/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/stock_price_2020_2021.pkl')
print(df.shape)
print(df.REFRESH_DATE.min())
print(df.Stock.nunique())
df.dtypes
# Out:
# (2178988, 9)
# 2021-08-15 00:00:00
# 5991
# Date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Volume                 float64
# SE                      object
# Stock                   object
# REFRESH_DATE    datetime64[ns]
# dtype: object

# %%
df.head(5)
# Out:
#         Date  Open  High   Low  Close   Volume      SE Stock REFRESH_DATE
# 0 2020-01-02  1.35  1.38  1.35   1.35   4300.0  NASDAQ  AACG   2021-08-15
# 1 2020-01-03  1.36  1.49  1.36   1.47  42000.0  NASDAQ  AACG   2021-08-15
# 2 2020-01-06  1.51  1.51  1.36   1.43  18700.0  NASDAQ  AACG   2021-08-15
# 3 2020-01-07  1.39  1.44  1.36   1.43  13700.0  NASDAQ  AACG   2021-08-15
# 4 2020-01-08  1.41  1.58  1.36   1.51  90900.0  NASDAQ  AACG   2021-08-15

# %% [markdown]
# ### Company Mapping

# %%
com_map=pd.read_sql("""SELECT * FROM NYSE_NASDAQ_TICKERS""",con=engine)
print(com_map.shape)
print(com_map.Symbol.nunique())
# Out:
# (5991, 12)
# 5991

# %% [markdown]
# ## Checking

# %% [markdown]
# ### NAs and Negative

# %%
## NAs
pd.DataFrame({'vals':df.isnull().sum()}).loc[lambda x:x.vals>0]
# Out:
#         vals
# Open     171
# High     171
# Low      171
# Close    171
# Volume   171

# %%
#df.loc[df.Open.isnull(),:]

# %%
## Negative
pd.DataFrame({'vals':df.select_dtypes(include=['float64']).apply(lambda x:(x<0).astype(int).sum())}).loc[lambda x:x.vals>0]
# Out:
#        vals
# Open    304
# High    304
# Low     304
# Close   304

# %%
df.loc[df.Open<0][:5]
# Out:
#               Date      Open      High       Low     Close      Volume    SE  \
# 1173045 2020-01-02 -4.621460 -4.629507 -4.501654 -4.522218   6605000.0  NYSE
# 1173046 2020-01-03 -4.507019 -4.614308 -4.496290 -4.593744   8263300.0  NYSE
# 1173047 2020-01-06 -4.586591 -4.635765 -4.556193 -4.622354  16151000.0  NYSE
# 1173048 2020-01-07 -4.600896 -4.623248 -4.549934 -4.562451  11878100.0  NYSE
# 1173049 2020-01-08 -4.566028 -4.608943 -4.559770 -4.583015   9504100.0  NYSE
#
#         Stock REFRESH_DATE
# 1173045   AIV   2021-08-15
# 1173046   AIV   2021-08-15
# 1173047   AIV   2021-08-15
# 1173048   AIV   2021-08-15
# 1173049   AIV   2021-08-15

# %% [markdown]
# ## Spot checking

# %%
df_temp=df.loc[df.Stock.isin(['CRM','MSFT','AAPL','NDAQ']),:]
print(
    ggplot(df_temp,
           aes('Date','Close',color='Stock'))
    +geom_line()
    +geom_text(aes(label='close_re'),
              df_temp.loc[df_temp.Date==df_temp.Date.max(),:].assign(close_re=lambda x:round(x.Close,0))
              )
    +scale_x_datetime(date_labels='%Y-%m')
    +theme(figure_size=(12,4))
    +labs(title='Stock Prices')
)
#print(
#    ggplot(df.loc[df.Stock=='MSFT',:],aes('Date','Close'))
#    +geom_line(color='orange')
#    +scale_x_datetime(date_labels='%Y-%m')
#    +theme(figure_size=(12,4))
#    +labs(title='MSFT')
#)

# %% [markdown]
# # 01 Correlation

# %% [markdown]
# ### For Loop

# %% [raw]
# col=[]
#
# for i in df.Stock.unique():
#     msft=df.loc[df.Stock=='MSFT','Close'].reset_index(drop=True)
#     if i=='MSFT':
#         continue
#     corr_coef=msft.corr(df.loc[df.Stock==i,'Close'].reset_index(drop=True))
#     result={'Stock':i,
#             'Close_corr':corr_coef,
#             'Latest_close_price':df.loc[(df.Stock==i)&(df.Date==df.Date.max()),'Close'],
#             'max_date':df.Date.max()
#            }
#     col.append(result)

# %% [markdown]
# ## Function

# %%
def stock_correlate(benchmark_stock=None):
    if benchmark_stock==None:
        benchmark_stock='MSFT' 
    benchmark=df.loc[df.Stock==benchmark_stock,'Close'].reset_index(drop=True)
    col=[]
    for i in df.Stock.unique():
        if i==benchmark_stock:
            continue
        corr_coef=benchmark.corr(df.loc[df.Stock==i,'Close'].reset_index(drop=True))
        result={'Stock':i,
                'Close_corr':corr_coef,
                'Latest_close_price':np.asscalar(df.loc[(df.Stock==i)&(df.Date==df.Date.max()),'Close']),
                'max_date':df.Date.max(),
                'num_records':df.loc[df.Stock==i,:].shape
               }
        col.append(result)
    return col

# %%
## Output
curr_time=datetime.datetime.now()

corr_analysis=pd.DataFrame(stock_correlate())

print(datetime.datetime.now()-curr_time)
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   if sys.path[0] == '':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-192-0ad134802cf4> in <module>
#       2 curr_time=datetime.datetime.now()
#       3
# ----> 4 corr_analysis=pd.DataFrame(stock_correlate())
#       5
#       6 print(datetime.datetime.now()-curr_time)
#
# <ipython-input-191-706f43c1f72a> in stock_correlate(benchmark_stock)
#      10         result={'Stock':i,
#      11                 'Close_corr':corr_coef,
# ---> 12                 'Latest_close_price':np.asscalar(df.loc[(df.Stock==i)&(df.Date==df.Date.max()),'Close']),
#      13                 'max_date':df.Date.max(),
#      14                 'num_records':df.loc[df.Stock==i,:].shape
#
# <__array_function__ internals> in asscalar(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/type_check.py in asscalar(a)
#     573     24
#     574     """
# --> 575     return a.item()
#     576
#     577 #-----------------------------------------------------------------------------
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in item(self)
#     738             stacklevel=2,
#     739         )
# --> 740         return self.values.item()
#     741
#     742     @property
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
corr_analysis.sort_values(by='Close_corr',ascending=False)
# Out:
#      Stock  Close_corr    Latest_close_price   max_date
# 656   CLNN    1.000000   [7.309999942779541] 2021-09-14
# 910   DPRO    1.000000   [3.559999942779541] 2021-09-14
# 1005  ENVB    1.000000  [2.9700000286102295] 2021-09-14
# 4005   CRL    0.975700    [436.239990234375] 2021-09-14
# 2115  NDAQ    0.971940   [195.5500030517578] 2021-09-14
# ...    ...         ...                   ...        ...
# 1404  HCWB   -0.907990   [4.260000228881836] 2021-09-14
# 3061  TLMD   -0.908841  [2.8399999141693115] 2021-09-14
# 5987  MCAF         NaN   [9.760000228881836] 2021-09-14
# 5988   OEG         NaN   [3.119999885559082] 2021-09-14
# 5989    UK         NaN  [0.9853000044822693] 2021-09-14
#
# [5990 rows x 4 columns]

# %%
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   """Entry point for launching an IPython kernel.
# 299.7900085449219

# %% [markdown]
# ### Mapping

# %%
corr_analysis_2=pd.merge(corr_analysis,
                         com_map.loc[:,['Symbol','Name','Sector','Industry','SE']],
                         how='left',
                         left_on='Stock',right_on='Symbol'
                        )
print(corr_analysis.shape)
print(corr_analysis_2.shape)
# Out:
# (5990, 4)
# (5990, 9)

# %%
corr_analysis_2.sort_values(by='Close_corr',ascending=False)
# Out:
#      Stock  Close_corr    Latest_close_price   max_date Symbol  \
# 656   CLNN    1.000000   [7.309999942779541] 2021-09-14   CLNN
# 910   DPRO    1.000000   [3.559999942779541] 2021-09-14   DPRO
# 1005  ENVB    1.000000  [2.9700000286102295] 2021-09-14   ENVB
# 4005   CRL    0.975700    [436.239990234375] 2021-09-14    CRL
# 2115  NDAQ    0.971940   [195.5500030517578] 2021-09-14   NDAQ
# ...    ...         ...                   ...        ...    ...
# 1404  HCWB   -0.907990   [4.260000228881836] 2021-09-14   HCWB
# 3061  TLMD   -0.908841  [2.8399999141693115] 2021-09-14   TLMD
# 5987  MCAF         NaN   [9.760000228881836] 2021-09-14   MCAF
# 5988   OEG         NaN   [3.119999885559082] 2021-09-14    OEG
# 5989    UK         NaN  [0.9853000044822693] 2021-09-14     UK
#
#                                                    Name             Sector  \
# 656                             Clene Inc. Common Stock  Consumer Durables
# 910                        Draganfly Inc. Common Shares  Consumer Durables
# 1005              Enveric Biosciences Inc. Common Stock        Health Care
# 4005  Charles River Laboratories International Inc. ...  Consumer Services
# 2115                           Nasdaq Inc. Common Stock               None
# ...                                                 ...                ...
# 1404                    HCW Biologics Inc. Common Stock               None
# 3061              SOC Telemed Inc. Class A Common Stock        Health Care
# 5987   Mountain Crest Acquisition Corp. IV Common Stock               None
# 5988             Orbital Energy Group Inc. Common Stock               None
# 5989         Ucommune International Ltd Ordinary Shares      Miscellaneous
#
#                    Industry      SE
# 656     Specialty Chemicals  NASDAQ
# 910   Electronic Components  NASDAQ
# 1005  Major Pharmaceuticals  NASDAQ
# 4005           EDP Services    NYSE
# 2115                   None  NASDAQ
# ...                     ...     ...
# 1404                   None  NASDAQ
# 3061    Managed Health Care  NASDAQ
# 5987                   None  NASDAQ
# 5988                   None  NASDAQ
# 5989      Business Services  NASDAQ
#
# [5990 rows x 9 columns]

# %%
#corr_analysis_2.to_csv('/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/analytics_result/MSFT_Corr.csv',
#                       index=False)

# %% [markdown]
# ## Analyze

# %% [markdown]
# ### Raw

# %%
corr_analysis_2.sort_values(by='Close_corr',ascending=False,inplace=True)
corr_analysis_2
# Out:
#      Stock  Close_corr    Latest_close_price   max_date Symbol  \
# 656   CLNN    1.000000   [7.309999942779541] 2021-09-14   CLNN
# 910   DPRO    1.000000   [3.559999942779541] 2021-09-14   DPRO
# 1005  ENVB    1.000000  [2.9700000286102295] 2021-09-14   ENVB
# 4005   CRL    0.975700    [436.239990234375] 2021-09-14    CRL
# 2115  NDAQ    0.971940   [195.5500030517578] 2021-09-14   NDAQ
# ...    ...         ...                   ...        ...    ...
# 1404  HCWB   -0.907990   [4.260000228881836] 2021-09-14   HCWB
# 3061  TLMD   -0.908841  [2.8399999141693115] 2021-09-14   TLMD
# 5987  MCAF         NaN   [9.760000228881836] 2021-09-14   MCAF
# 5988   OEG         NaN   [3.119999885559082] 2021-09-14    OEG
# 5989    UK         NaN  [0.9853000044822693] 2021-09-14     UK
#
#                                                    Name             Sector  \
# 656                             Clene Inc. Common Stock  Consumer Durables
# 910                        Draganfly Inc. Common Shares  Consumer Durables
# 1005              Enveric Biosciences Inc. Common Stock        Health Care
# 4005  Charles River Laboratories International Inc. ...  Consumer Services
# 2115                           Nasdaq Inc. Common Stock               None
# ...                                                 ...                ...
# 1404                    HCW Biologics Inc. Common Stock               None
# 3061              SOC Telemed Inc. Class A Common Stock        Health Care
# 5987   Mountain Crest Acquisition Corp. IV Common Stock               None
# 5988             Orbital Energy Group Inc. Common Stock               None
# 5989         Ucommune International Ltd Ordinary Shares      Miscellaneous
#
#                    Industry      SE
# 656     Specialty Chemicals  NASDAQ
# 910   Electronic Components  NASDAQ
# 1005  Major Pharmaceuticals  NASDAQ
# 4005           EDP Services    NYSE
# 2115                   None  NASDAQ
# ...                     ...     ...
# 1404                   None  NASDAQ
# 3061    Managed Health Care  NASDAQ
# 5987                   None  NASDAQ
# 5988                   None  NASDAQ
# 5989      Business Services  NASDAQ
#
# [5990 rows x 9 columns]

# %%
## Filtering
corr_analysis_3=corr_analysis_2.loc[corr_analysis_2.Close_corr<1,:].reset_index(drop=True)
print(corr_analysis_3.shape)
corr_analysis_3.head(25)
## DT
## BKT
## AXNX
## AVTR
# ARES
# Out:
# (5984, 9)
#    Stock  Close_corr    Latest_close_price   max_date Symbol  \
# 0    CRL    0.975700    [436.239990234375] 2021-09-14    CRL
# 1   NDAQ    0.971940   [195.5500030517578] 2021-09-14   NDAQ
# 2   IDXX    0.971393   [661.3900146484375] 2021-09-14   IDXX
# 3   EPAM    0.970015   [622.7100219726562] 2021-09-14   EPAM
# 4    ACN    0.968068   [340.7200012207031] 2021-09-14    ACN
# 5   NVDA    0.967178   [222.4199981689453] 2021-09-14   NVDA
# 6   ODFL    0.966903   [288.6600036621094] 2021-09-14   ODFL
# 7     DT    0.966765   [70.61000061035156] 2021-09-14     DT
# 8   INTU    0.966558     [568.27001953125] 2021-09-14   INTU
# 9      A    0.965861   [172.4199981689453] 2021-09-14      A
# 10   BKT    0.965822   [6.429999828338623] 2021-09-14    BKT
# 11   VRT    0.965333  [23.639999389648438] 2021-09-14    VRT
# 12   WST    0.963839  [452.05999755859375] 2021-09-14    WST
# 13  DSGX    0.963738   [82.41999816894531] 2021-09-14   DSGX
# 14  HUBS    0.962796   [671.8300170898438] 2021-09-14   HUBS
# 15  ZENV    0.962762  [15.960000038146973] 2021-09-14   ZENV
# 16  AXNX    0.962627   [70.44000244140625] 2021-09-14   AXNX
# 17  MSCI    0.962236     [653.27001953125] 2021-09-14   MSCI
# 18   DHR    0.962204   [324.0899963378906] 2021-09-14    DHR
# 19  ASML    0.961735   [888.0700073242188] 2021-09-14   ASML
# 20   ETJ    0.961017  [10.989999771118164] 2021-09-14    ETJ
# 21  AVTR    0.959842    [42.0099983215332] 2021-09-14   AVTR
# 22  ARES    0.959820   [78.22000122070312] 2021-09-14   ARES
# 23  TECH    0.959409   [509.8900146484375] 2021-09-14   TECH
# 24    FB    0.959384   [376.5299987792969] 2021-09-14     FB
#
#                                                  Name             Sector  \
# 0   Charles River Laboratories International Inc. ...  Consumer Services
# 1                            Nasdaq Inc. Common Stock               None
# 2                IDEXX Laboratories Inc. Common Stock        Health Care
# 3                      EPAM Systems Inc. Common Stock         Technology
# 4     Accenture plc Class A Ordinary Shares (Ireland)         Technology
# 5                     NVIDIA Corporation Common Stock         Technology
# 6         Old Dominion Freight Line Inc. Common Stock     Transportation
# 7                         Dynatrace Inc. Common Stock         Technology
# 8                            Intuit Inc. Common Stock         Technology
# 9              Agilent Technologies Inc. Common Stock      Capital Goods
# 10                  BlackRock Income Trust Inc. (The)            Finance
# 11           Vertiv Holdings LLC Class A Common Stock  Consumer Durables
# 12     West Pharmaceutical Services Inc. Common Stock   Basic Industries
# 13    Descartes Systems Group Inc. (The) Common Stock               None
# 14                          HubSpot Inc. Common Stock         Technology
# 15                   Zenvia Inc. Class A Common Stock               None
# 16                          Axonics Inc. Common Stock        Health Care
# 17                              MSCI Inc Common Stock      Miscellaneous
# 18                   Danaher Corporation Common Stock      Capital Goods
# 19         ASML Holding N.V. New York Registry Shares         Technology
# 20  Eaton Vance Risk-Managed Diversified Equity In...            Finance
# 21                          Avantor Inc. Common Stock      Capital Goods
# 22   Ares Management Corporation Class A Common Stock            Finance
# 23                       Bio-Techne Corp Common Stock        Health Care
# 24                 Facebook Inc. Class A Common Stock         Technology
#
#                                              Industry      SE
# 0                                        EDP Services    NYSE
# 1                                                None  NASDAQ
# 2   Biotechnology: In Vitro & In Vivo Diagnostic S...  NASDAQ
# 3                                        EDP Services    NYSE
# 4                                        EDP Services    NYSE
# 5                                      Semiconductors  NASDAQ
# 6                   Trucking Freight/Courier Services  NASDAQ
# 7                                        EDP Services    NYSE
# 8             Computer Software: Prepackaged Software  NASDAQ
# 9                                 Electrical Products    NYSE
# 10  Trusts Except Educational Religious and Charit...    NYSE
# 11                                Electrical Products    NYSE
# 12                                Specialty Chemicals    NYSE
# 13                                               None  NASDAQ
# 14            Computer Software: Prepackaged Software    NYSE
# 15                                               None  NASDAQ
# 16                         Medical/Dental Instruments  NASDAQ
# 17                                  Business Services    NYSE
# 18                    Industrial Machinery/Components    NYSE
# 19                    Industrial Machinery/Components  NASDAQ
# 20                                  Finance Companies    NYSE
# 21   Biotechnology: Laboratory Analytical Instruments    NYSE
# 22                                Investment Managers    NYSE
# 23  Biotechnology: Biological Products (No Diagnos...  NASDAQ
# 24                  Internet and Information Services  NASDAQ

# %% [markdown]
# ### Viz

# %%
df_temp=df.loc[df.Stock.isin(['NVDA','DT','A','VRT','DSGX','AXNX','AVTR','FB']),:] # 'CRM','MSFT','CRL',
print(
    ggplot(df_temp,
           aes('Date','Close',color='Stock'))
    +geom_line()
    +geom_text(aes(label='close_re'),
              df_temp.loc[(df_temp.Date==df_temp.Date.max())|
                          (df_temp.Date==df_temp.Date.min())
                          ,:].assign(close_re=lambda x:round(x.Close,0))
              )
    +scale_x_datetime(date_labels='%Y-%m')
    +scale_y_continuous(breaks=np.arange(0,df_temp.Close.max(),10))
    +theme(figure_size=(12,6))
    +labs(title='Stock Prices')
)
# Out:
# <ggplot: (8731729206321)>

# %% [markdown]
# ### Parallel Processing
# *  Parallel with dask: https://github.com/dask/dask-tutorial/blob/main/01_dask.delayed.ipynb

# %%
from dask import delayed # conda install dask
from dask.distributed import Client, LocalCluster
#client=Client(n_workers=2)
#LocalCluster()

# %%
client=Client(n_workers=16)

# %%
col=[]
for i in df.Stock.unique():
    benchmark=df.loc[df.Stock=='MSFT','Close'].reset_index(drop=True)
    if i=='MSFT':
        continue
    corr_coef=delayed(pd.Series.corr)(benchmark, 
                                      df.loc[df.Stock==i,'Close'].reset_index(drop=True))
    result={'Stock':i,
            'Close_corr':corr_coef}
    col.append(result)

total=delayed(pd.DataFrame)(col)
corr_output=total.compute()

# %%
client.close()

# %% [markdown]
# # Linear Regression

# %%
import statsmodels.formula.api as smf

# %% [markdown]
# ## 01 Data Preprocessing

# %%
df_1=df.copy()
df_1.loc[:,'REPORT_DATE']=df_1.loc[:,'Date']
## Calculating Days
df_1.loc[:,'Days']=df_1.groupby('Stock').REPORT_DATE.transform(lambda x:x.rank(method='dense',ascending=True))

# %% [markdown]
# ## 02 Regression

# %%
curr_time=datetime.datetime.now()

col_model=[]
for v in df_1.Stock.unique():
    sub_df=df_1.loc[df_1.Stock==v,:].sort_values(by='Date',ascending=True).reset_index(drop=True)
    lr_model=smf.ols('Close ~ Days',data=sub_df).fit()
    
    model_result={'Stock':v,
                  'R_squared':lr_model.rsquared,
                  'Coef':lr_model.params[1],
                  'Start_Date':sub_df.loc[0,'Date'],
                  'End_Date':sub_df.iloc[-1,:]['Date'],
                  'Start_Price':sub_df.loc[0,'Close'],
                  'End_Price':sub_df.iloc[-1,:].Close,
                  'Num_records':sub_df.shape[0],
                  'Num_records_2':sub_df.Date.nunique()
                  
                 }
    
    col_model.append(model_result)
    
print(datetime.datetime.now()-curr_time)
# Out:
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:
remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50248 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50250 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50252 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50254 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50256 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50258 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50260 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50262 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50264 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50266 remote=tcp://127.0.0.1:38403>
# ...
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50538 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50540 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50542 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50544 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50546 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50548 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50550 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50552 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50554 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50556 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50558 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50560 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50562 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50564 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50566 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50568 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50570 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50572 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50574 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50576 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50578 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50580 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50582 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50584 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50586 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50588 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50590 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50592 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50594 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50596 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50598 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50600 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50602 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50604 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50606 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50608 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50610 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50612 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50614 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50616 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50618 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50620 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50622 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50624 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50626 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50628 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50630 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50632 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50634 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50636 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50638 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50640 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50642 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50644 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50646 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50648 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50650 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50652 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50654 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50656 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50658 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50660 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50662 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50664 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50666 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50668 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50670 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50672 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50674 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50676 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50678 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50680 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50682 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50684 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50686 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50688 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50690 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50692 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50694 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50696 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50698 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50700 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50702 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50704 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50706 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50708 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50710 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50712 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50714 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50716 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50718 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50720 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50722 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50724 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50726 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50728 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50730 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50732 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50734 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50736 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50738 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50740 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50742 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50744 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50746 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50748 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50750 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50752 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50754 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50756 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50758 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50760 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50762 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50764 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50766 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50768 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50770 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50772 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50774 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50776 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50778 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50780 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50782 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50784 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50786 remote=tcp://127.0.0.1:38403>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50788 remote=tcp://127.0.0.1:38403>
# 0:14:31.497790
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1636: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP  local=tcp://127.0.0.1:50790 remote=tcp://127.0.0.1:38403>

# %%
col_model_2=pd.read_csv('/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/analytics_result/linear_reg_results.csv')

#col_model_2=pd.DataFrame(col_model)
## Saving
#col_model_2.to_csv('/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/analytics_result/linear_reg_results.csv',
#                   index=False)
print(col_model_2.shape)
print(col_model_2.Stock.nunique())
# Out:
# (5991, 9)
# 5991

# %% [markdown]
# ## 03 Analysis

# %% [markdown]
# ### Data Cleaning

# %%
col_model_2.sort_values(by='R_squared',ascending=False)
# Out:
#      Stock     R_squared      Coef Start_Date   End_Date  Start_Price  \
# 1005  ENVB  1.000000e+00 -1.010000 2021-01-04 2021-09-14     3.980000
# 910   DPRO  1.000000e+00 -0.240000 2021-07-30 2021-09-14     3.800000
# 656   CLNN  1.000000e+00 -0.260000 2021-01-04 2021-09-14     7.570000
# 5489    SE  9.631383e-01  0.701782 2020-01-02 2021-09-14    40.040001
# 4804   LFT  9.603078e-01  0.007905 2020-06-30 2021-09-14     2.364295
# ...    ...           ...       ...        ...        ...          ...
# 4117   DMS  6.428270e-08  0.000004 2020-01-02 2021-09-14    10.350000
# 5584    SR  5.040268e-09 -0.000005 2020-01-02 2021-09-14    78.055885
# 5988  MCAF          -inf  4.880000 2021-09-14 2021-09-14     9.760000
# 5989   OEG          -inf  1.560000 2021-09-14 2021-09-14     3.120000
# 5990    UK          -inf  0.492650 2021-09-14 2021-09-14     0.985300
#
#        End_Price  Num_records  Num_records_2
# 1005    2.970000            2              2
# 910     3.560000            2              2
# 656     7.310000            2              2
# 5489  333.549988          423            423
# 4804    3.990000          298            298
# ...          ...          ...            ...
# 4117    7.040000          420            420
# 5584   62.869999          424            424
# 5988    9.760000            1              1
# 5989    3.120000            1              1
# 5990    0.985300            1              1
#
# [5991 rows x 9 columns]

# %%
col_model_2.loc[col_model_2.Num_records!=col_model_2.Num_records_2]
# Out:
# Empty DataFrame
# Columns: [Stock, R_squared, Coef, Start_Date, End_Date, Start_Price, End_Price, Num_records, Num_records_2]
# Index: []

# %%
## Num_records distribution
print(
    ggplot(col_model_2,aes('Num_records'))
    +geom_histogram(bins=30)
)
# Out:
# <ggplot: (8731728265761)>

# %%
## Only consider >100
col_model_fil=col_model_2.loc[col_model_2.Num_records>=100,:].reset_index(drop=True)
print(col_model_fil.shape)
# Out:
# (5555, 9)

# %%
## Merge with info
col_model_fil=pd.merge(col_model_fil,
                       com_map.loc[:,['Symbol','Name','Sector','Industry','SE']],
                       how='left',
                       left_on='Stock',right_on='Symbol'
                      )
print(col_model_fil.shape)
print(col_model_fil.Stock.nunique())
# Out:
# (5555, 14)
# 5555

# %%
## Calculate weighted Coef
#col_model_fil.loc[:,'wt_Coef']=col_model_fil.R_squared*col_model_fil.Coef
#col_model_fil.to_csv('/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/analytics_result/linear_reg_results_filtered.csv',
#                    index=False)
col_model_fil=pd.read_csv('/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/analytics_result/linear_reg_results_filtered.csv')

# %% [markdown]
# ### Analyzing

# %%
## R_squared and Coef distribution
col_model_fil.loc[:,['R_squared','Coef']].describe()
# Out:
#           R_squared         Coef
# count  5.555000e+03  5555.000000
# mean   4.469730e-01     0.008934
# std    2.760174e-01     3.760988
# min    5.040268e-09  -243.999525
# 25%    2.005110e-01     0.001025
# 50%    4.716821e-01     0.014194
# 75%    6.872602e-01     0.049965
# max    9.631383e-01   101.626236

# %% [markdown]
# #### 01. Build a profolio that doesn't own the whole stock

# %%
## rank by wt_coef
profolio_partial=col_model_fil.sort_values(by='wt_Coef',ascending=False)
profolio_partial.head(25).Sector.value_counts()
# Out:
# Technology           6
# Finance              4
# Consumer Services    4
# Health Care          4
# Capital Goods        2
# Transportation       1
# Energy               1
# Name: Sector, dtype: int64

# %%
profolio_partial
# Out:
#       Stock  R_squared        Coef  Start_Date    End_Date  Start_Price  \
# 2499    SCR   0.637444  101.626236  2021-02-23  2021-09-14  8450.000000
# 4743    NVR   0.719497    4.970474  2020-01-02  2021-09-14  3735.500000
# 1203   GOOG   0.876698    3.711630  2020-01-02  2021-09-14  1367.369995
# 1204  GOOGL   0.876541    3.581791  2020-01-02  2021-09-14  1368.680054
# 175    AMZN   0.730067    3.671435  2020-01-02  2021-09-14  1898.010010
# 1776   MELI   0.775146    3.067222  2020-01-02  2021-09-14   610.190002
# 5103   SHOP   0.868287    2.546581  2020-01-02  2021-09-14   407.809998
# 3624    CMG   0.850839    2.372296  2020-01-02  2021-09-14   858.190002
# 5301    TPL   0.651217    2.894460  2020-01-02  2021-09-14   742.016052
# 4592    MTD   0.916523    2.003578  2020-01-02  2021-09-14   805.059998
# 2837   TSLA   0.812308    1.794679  2020-01-02  2021-09-14    86.052002
# 5000     RH   0.928964    1.502571  2020-01-02  2021-09-14   211.500000
# 247    ASML   0.921206    1.326825  2020-01-02  2021-09-14   299.266418
# 1875   MSTR   0.690646    1.759354  2020-01-02  2021-09-14   144.309998
# 4221   HUBS   0.941002    1.275099  2020-01-02  2021-09-14   162.570007
# 2842             Technology
# 3143          Capital Goods
# 921   Consumer Non-Durables
# 1289      Consumer Services
# 5535      Consumer Services
# 544   Consumer Non-Durables
# 5186                   None
# 1896       Basic Industries
# 2006          Capital Goods
# 4951          Capital Goods
# 1357            Health Care
# 1406            Health Care
#
#                                                Industry      SE   wt_Coef
# 1037                                       EDP Services  NASDAQ  0.286601
# 2665                                   Ophthalmic Goods  NASDAQ  0.282629
# 5329                                  Auto Parts:O.E.M.    NYSE  0.264148
# 3969                    Industrial Machinery/Components    NYSE  0.261458
# 3757                               Oil & Gas Production    NYSE  0.260914
# 1773  Biotechnology: Commercial Physical & Biologica...  NASDAQ  0.257974
# 1569                    Industrial Machinery/Components  NASDAQ  0.236471
# 1103                                               None  NASDAQ  0.228964
# 4650                                       EDP Services    NYSE  0.226585
# 5492                                  Building Products    NYSE  0.219365
# 2864                                     Semiconductors  NASDAQ  0.211946
# 5257                                        Advertising    NYSE  0.201558
# 1679                      Computer peripheral equipment  NASDAQ  0.196836
# 2842   Retail: Computer Software & Peripheral Equipment  NASDAQ  0.194458
# 3143                                Electrical Products    NYSE  0.193428
# 921                                    Plastic Products  NASDAQ  0.191075
# 1289                             Other Specialty Stores  NASDAQ  0.186092
# 5535                               Movies/Entertainment    NYSE  0.181180
# 544                 Beverages (Production/Distribution)  NASDAQ  0.180636
# 5186                                               None    NYSE  0.176387
# 1896                                       Water Supply  NASDAQ  0.175389
# 2006                              Electronic Components  NASDAQ  0.173661
# 4951                         Engineering & Construction    NYSE  0.171308
# 1357                              Major Pharmaceuticals  NASDAQ  0.167170
# 1406                              Major Pharmaceuticals  NASDAQ  0.158445

# %%
## Viz
df_temp=df.loc[df.Stock.isin(['TXN','LOGI','IMAB']),:] # 'CRM','MSFT','CRL',
print(
    ggplot(df_temp,
           aes('Date','Close',color='Stock'))
    +geom_line()
    +geom_text(aes(label='close_re'),
              df_temp.loc[(df_temp.Date==df_temp.Date.max())|
                          (df_temp.Date==df_temp.Date.min())
                          ,:].assign(close_re=lambda x:round(x.Close,0))
              )
    +scale_x_datetime(date_labels='%Y-%m')
    +scale_y_continuous(breaks=np.arange(0,df_temp.Close.max(),50))
    +theme(figure_size=(12,6))
    +labs(title='Stock Prices')
)
# Out:
# <ggplot: (8774576797269)>

# %%
## Add last 30 days moving average

# %% [markdown]
# # Moving Average

# %% [markdown]
# ## Preprocessing

# %%
## 01 Sorting
df_2=df.copy()
df_2.sort_values(by=['Stock','Date'],ascending=True,inplace=True)
df_2.head(10)
# Out:
#               Date       Open       High        Low      Close     Volume  \
# 1144938 2020-01-02  84.967629  85.412742  84.275223  85.017082  1410500.0
# 1144939 2020-01-03  83.750990  84.403830  83.582837  83.652077  1118300.0
# 1144940 2020-01-06  83.088254  83.899353  82.692594  83.899353  1993200.0
# 1144941 2020-01-07  83.048686  84.334579  83.028907  84.156532  1684700.0
# 1144942 2020-01-08  85.026978  85.531445  84.275225  84.987411  1847600.0
# 1144943 2020-01-09  85.521563  86.748102  85.234710  86.322769  1912700.0
# 1144944 2020-01-10  86.767876  87.282229  86.372216  86.639282  1417000.0
# 1144945 2020-01-13  86.856904  87.361370  85.798518  86.510704  1630200.0
# 1144946 2020-01-14  86.322764  87.252564  85.758951  87.034950  1675200.0
# 1144947 2020-01-15  86.678859  88.142799  86.599733  87.658119  1630400.0
#
#            SE Stock REFRESH_DATE
# 1144938  NYSE     A   2021-08-15
# 1144939  NYSE     A   2021-08-15
# 1144940  NYSE     A   2021-08-15
# 1144941  NYSE     A   2021-08-15
# 1144942  NYSE     A   2021-08-15
# 1144943  NYSE     A   2021-08-15
# 1144944  NYSE     A   2021-08-15
# 1144945  NYSE     A   2021-08-15
# 1144946  NYSE     A   2021-08-15
# 1144947  NYSE     A   2021-08-15

# %%
## 02 moving average
# df.loc[:,['SE','Stock']].drop_duplicates().Stock.value_counts()  #stock is distinct
df_2.loc[:,'Close_m30_avg']=df_2.groupby('Stock').Close.transform(lambda x:x.rolling(30,min_periods=1).mean())
df_2.loc[:,'PCT_CHANGE']=df_2.groupby('Stock').Close.transform(lambda x:x.pct_change())

# average 3 month daily growth rate

# %% [raw]
# ## 03 average PCT_CHANGE in the last 30 days
# results=[]
#
# for i in df_2.Stock.unique():
#     count=0
#     col=0
#     for x in df_2.loc[df_2.Stock==i,'PCT_CHANGE'][-30:]:
#         if x==None:
#             continue
#         col+=x
#         count+=1
#
#     summary={'Stock':i,
#              'avg_l30_PCT_CHANHE':col/count}
#
#     results.append(summary)

# %%
def last_3m_avg_growth(x):
    count=0
    col=0
    for x in x[-30:]:
        if ~np.isnan(x):
            col+=x
            count+=1
    if count>0:
        output=col/count
    else:
        output=np.nan
        
    return output

df_2.loc[:,'last_3m_avg_PCT_CHANGE']=df_2.groupby('Stock').PCT_CHANGE.transform(lambda x:last_3m_avg_growth(x))

# %%
## Saving
#joblib.dump(df_2,'/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/analytics_result/stock_price_2020_2021_adjusted.pkl')

## Loading
df_2=joblib.load('/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/analytics_result/stock_price_2020_2021_adjusted.pkl')
# Out:
# ['/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/analytics_result/stock_price_2020_2021_adjusted.pkl']

# %%
df_2.isnull().sum()
# Out:
# Date                         0
# Open                       171
# High                       171
# Low                        171
# Close                      171
# Volume                     171
# SE                           0
# Stock                        0
# REFRESH_DATE                 0
# Close_m30_avg                1
# PCT_CHANGE                5992
# last_3m_avg_PCT_CHANGE       3
# dtype: int64

# %%
df_2.loc[df_2.last_3m_avg_PCT_CHANGE.isnull(),:]
# Out:
#               Date    Open    High   Low   Close     Volume      SE Stock  \
# 2174852 2021-09-14  9.7600  9.7600  9.76  9.7600      317.0  NASDAQ  MCAF
# 2175169 2021-09-14  3.2000  3.2612  3.08  3.1200  1652994.0  NASDAQ   OEG
# 2176070 2021-09-14  0.9903  0.9999  0.98  0.9853    38180.0  NASDAQ    UK
#
#                REFRESH_DATE  Close_m30_avg  PCT_CHANGE  last_3m_avg_PCT_CHANGE
# 2174852 2021-09-14 23:40:04         9.7600         NaN                     NaN
# 2175169 2021-09-14 23:40:04         3.1200         NaN                     NaN
# 2176070 2021-09-14 23:40:04         0.9853         NaN                     NaN

# %%
df_2.loc[df_2.Stock=='LOGI',:]
# Out:
#               Date        Open        High         Low       Close  \
# 610451  2020-01-02   46.762743   47.108404   46.673859   47.078773
# 610452  2020-01-03   46.644234   46.940512   46.446713   46.624481
# 610453  2020-01-06   46.170185   46.644232   46.110928   46.594852
# 610454  2020-01-07   46.822002   46.861507   46.604729   46.723244
# 610455  2020-01-08   46.970143   47.207164   46.782497   47.029396
# ...            ...         ...         ...         ...         ...
# 2150812 2021-08-31  103.620003  103.989998  102.019997  102.349998
# 2150813 2021-09-01  103.440002  104.529999  103.129997  103.430000
# 2150814 2021-09-02  102.919998  103.070000  101.089996  101.230003
# 2150815 2021-09-03  102.870003  103.459999  102.470001  102.870003
# 2174776 2021-09-14  100.050003  100.339996   98.640999   99.010002
#
#              Volume      SE Stock        REFRESH_DATE  Close_m30_avg  \
# 610451     176400.0  NASDAQ  LOGI 2021-08-15 00:00:00      47.078773
# 610452     254000.0  NASDAQ  LOGI 2021-08-15 00:00:00      46.851627
# 610453     164200.0  NASDAQ  LOGI 2021-08-15 00:00:00      46.766036
# 610454      95200.0  NASDAQ  LOGI 2021-08-15 00:00:00      46.755338
# 610455     142300.0  NASDAQ  LOGI 2021-08-15 00:00:00      46.810149
# ...             ...     ...   ...                 ...            ...
# 2150812  88730000.0  NASDAQ  LOGI 2021-09-07 23:38:19     108.934667
# 2150813  59750000.0  NASDAQ  LOGI 2021-09-07 23:38:19     108.343000
# 2150814  61780000.0  NASDAQ  LOGI 2021-09-07 23:38:19     107.707334
# 2150815  46800000.0  NASDAQ  LOGI 2021-09-07 23:38:19     107.127667
# 2174776    588386.0  NASDAQ  LOGI 2021-09-14 23:40:04     106.399000
#
#          PCT_CHANGE  last_3m_avg_PCT_CHANGE
# 610451          NaN               -0.006331
# 610452    -0.009650               -0.006331
# 610453    -0.000635               -0.006331
# 610454     0.002755               -0.006331
# 610455     0.006552               -0.006331
# ...             ...                     ...
# 2150812   -0.033431               -0.006331
# 2150813    0.010552               -0.006331
# 2150814   -0.021270               -0.006331
# 2150815    0.016201               -0.006331
# 2174776   -0.037523               -0.006331
#
# [424 rows x 12 columns]

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Viz

# %%
df_2.loc[df_2.Stock.isin(['LOGI','CRM','MSFT']),:].groupby('Stock').agg(avg_pct_change=('last_3m_avg_PCT_CHANGE','max'))
# Out:
#        avg_pct_change
# Stock
# CRM          0.001019
# LOGI        -0.006331
# MSFT         0.001251

# %%
df_temp=df_2.loc[df_2.Stock.isin(['LOGI','CRM','MSFT','FIVN']),:].melt(id_vars=['Date','SE','Stock'],
                                                                value_vars=['Close','Close_m30_avg'],
                                                                var_name='type',
                                                                value_name='vals'
                                                               )
print(
    ggplot(df_temp,aes('Date','vals',color='type'))
    +geom_line()
    +scale_x_datetime(date_breaks='14 day', date_labels='%Y-%m')
    +facet_grid('Stock~.',scales='free_y')
    +theme(axis_text_x=element_text(angle=90),figure_size=(12,8))
)
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8758623173969)>

# %% [markdown]
# ## Short Listing

# %%
## data loading
df_2=joblib.load('/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/analytics_result/stock_price_2020_2021_adjusted.pkl')
col_model_fil=pd.read_csv('/home/ubuntu/Python_Projects/Stock_Price_Prediction/data/analytics_result/linear_reg_results_filtered.csv')

print(df_2.shape)
print(col_model_fil.shape)
# Out:
# (2178988, 12)
# (5555, 15)

# %%
## Overprocessing
print(col_model_fil.shape)
print(df_2.Stock.nunique())

## df_2
df_3_si=df_2.loc[:,['Stock','last_3m_avg_PCT_CHANGE']].drop_duplicates()
print('df_3_si :',df_3_si.shape,df_3_si.Stock.nunique())

## 
col_model_fil_2=pd.merge(col_model_fil,df_3_si,
                         how='left',
                         on='Stock')
print('col_model_fil_2: ',col_model_fil_2.shape,col_model_fil_2.Stock.nunique())
# Out:
# (5555, 15)
# 5991
# df_3_si : (5991, 2) 5991
# col_model_fil_2:  (5555, 16) 5555

# %% [markdown]
# ###  Full Owning

# %%
profolio_full_2=col_model_fil_2.loc[(col_model_fil_2.End_Price<=200)&
                                    (col_model_fil_2.Coef>=0.05)&
                                    (col_model_fil_2.R_squared>=0.9)&
                                    (col_model_fil_2.last_3m_avg_PCT_CHANGE>0)
                                       ,:].sort_values(by='wt_Coef',ascending=False)
print(profolio_full_2.shape)
profolio_full_2
# Out:
# (40, 16)
#      Stock  R_squared      Coef  Start_Date    End_Date  Start_Price  \
# 2665  STAA   0.910625  0.310368  2020-01-02  2021-09-14    34.790001
# 3969  FERG   0.913247  0.286294  2020-09-10  2021-09-14    89.900963
# 3757   DEN   0.928489  0.281009  2020-09-21  2021-09-14    18.100000
# 1773  MEDP   0.911278  0.283090  2020-01-02  2021-09-14    82.970001
# 1569  KRNT   0.928675  0.254633  2020-01-02  2021-09-14    33.779999
# 1103   FSV   0.904474  0.253146  2020-01-02  2021-09-14    92.491524
# 4650   NET   0.913981  0.247911  2020-01-02  2021-09-14    17.030001
# 2864   TXN   0.903862  0.234489  2020-01-02  2021-09-14   123.730911
# 5257  TFII   0.916541  0.219911  2020-01-22  2021-09-14    33.073509
# 3143     A   0.921972  0.209798  2020-01-02  2021-09-14    85.017082
# 921   ENTG   0.933884  0.204602  2020-01-02  2021-09-14    50.598316
# 5535  YETI   0.935682  0.193634  2020-01-02  2021-09-14    34.900002
# 544   CELH   0.912152  0.198033  2020-01-02  2021-09-14     4.750000
# 5186  SSTK   0.905970  0.194695  2020-01-02  2021-09-14    41.883514
# 1896  MYRG   0.911788  0.192357  2020-01-02  2021-09-14    32.430000
# 2006  NVMI   0.939910  0.184764  2020-01-02  2021-09-14    37.950001
# 4951   PWR   0.916128  0.186992  2020-01-02  2021-09-14    40.842991
# 1357  HZNP   0.908809  0.183945  2020-01-02  2021-09-14    36.380001
# 1406  IMAB   0.934393  0.169570  2020-01-17  2021-09-14    12.500000
# 5310  TREX   0.909497  0.167889  2020-01-02  2021-09-14    45.180000
# 3756  DELL   0.912258  0.164746  2020-01-02  2021-09-14    52.290001
# 1968  NOTV   0.901108  0.147077  2020-09-23  2021-09-14     4.880000
# 2817  TRMB   0.903823  0.144038  2020-01-02  2021-09-14    41.939999
# 249    ASO   0.941144  0.133218  2020-10-02  2021-09-14    12.990000
# 544                 Beverages (Production/Distribution)  NASDAQ  0.180636
# 5186                                                NaN    NYSE  0.176387
# 1896                                       Water Supply  NASDAQ  0.175389
# 2006                              Electronic Components  NASDAQ  0.173661
# 4951                         Engineering & Construction    NYSE  0.171308
# 1357                              Major Pharmaceuticals  NASDAQ  0.167170
# 1406                              Major Pharmaceuticals  NASDAQ  0.158445
# 5310                                                NaN    NYSE  0.152694
# 3756                             Computer Manufacturing    NYSE  0.150291
# 1968                              Major Pharmaceuticals  NASDAQ  0.132532
# 2817                    Industrial Machinery/Components  NASDAQ  0.130185
# 249                          Recreational Products/Toys  NASDAQ  0.125377
# 1993            Computer Software: Prepackaged Software  NASDAQ  0.101791
# 162                  Investment Bankers/Brokers/Service  NASDAQ  0.101573
# 3535                             Wholesale Distributors    NYSE  0.101485
# 142             Computer Software: Prepackaged Software  NASDAQ  0.100388
# 1697                                     Semiconductors  NASDAQ  0.099926
# 5446                         Recreational Products/Toys    NYSE  0.092320
# 314                          Medical/Dental Instruments  NASDAQ  0.090911
# 2199                                Investment Managers  NASDAQ  0.087778
# 1822                         Medical/Dental Instruments  NASDAQ  0.077987
# 609                        Telecommunications Equipment  NASDAQ  0.077306
# 673                                               Banks  NASDAQ  0.071914
# 490                               Electronic Components  NASDAQ  0.071027
# 3489  Trusts Except Educational Religious and Charit...    NYSE  0.060906
# 4070                                                NaN    NYSE  0.054136
# 3337   Biotechnology: Laboratory Analytical Instruments    NYSE  0.054125
# 1604                             Other Specialty Stores  NASDAQ  0.053121
#
#       last_3m_avg_PCT_CHANGE
# 2665                0.004581
# 3969                0.000489
# 3757                0.002455
# 1773                0.000086
# 1569                0.003619
# 1103                0.000130
# 4650                0.002997
# 2864                0.001497
# 5257                0.002733
# 3143                0.004208
# 921                 0.002434
# 5535                0.000918
# 544                 0.010063
# 5186                0.002275
# 1896                0.002314
# 2006                0.002829
# 4951                0.008896
# 1357                0.001834
# 1406                0.000324
# 5310                0.002647
# 3756                0.000390
# 1968                0.002845
# 2817                0.003176
# 249                 0.007402
# 1993                0.000056
# 162                 0.004881
# 3535                0.002059
# 142                 0.002778
# 1697                0.006448
# 5446                0.001929
# 314                 0.001225
# 2199                0.002218
# 1822                0.003807
# 609                 0.002637
# 673                 0.004947
# 490                 0.007115
# 3489                0.000659
# 4070                0.003573
# 3337                0.004419
# 1604                0.001070

# %%
## Viz
df_temp=df_2.loc[df_2.Stock.isin(['FIVN','STAA','TT','WMS','AOS','DELL']),:].melt(id_vars=['Date','SE','Stock'],
                                                                value_vars=['Close','Close_m30_avg'],
                                                                var_name='type',
                                                                value_name='vals'
                                                               )
print(
    ggplot(df_temp,aes('Date','vals',color='type'))
    +geom_line()
    +scale_x_datetime(date_breaks='14 day', date_labels='%Y-%m')
    +facet_grid('Stock~.',scales='free_y')
    +theme(axis_text_x=element_text(angle=90),figure_size=(12,8))
)
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8758622406041)>

# %% [markdown]
# ### Partial owning

# %%
profolio_partial_2=col_model_fil_2.loc[(col_model_fil_2.End_Price>=200)&
                                       (col_model_fil_2.R_squared>=0.9)&
                                       (col_model_fil_2.last_3m_avg_PCT_CHANGE>0)
                                      ].sort_values(by='wt_Coef',ascending=False)
print(profolio_partial_2.shape)
profolio_partial_2
# Out:
# (20, 16)
#      Stock  R_squared      Coef  Start_Date    End_Date  Start_Price  \
# 4592   MTD   0.916523  2.003578  2020-01-02  2021-09-14   805.059998
# 5000    RH   0.928964  1.502571  2020-01-02  2021-09-14   211.500000
# 247   ASML   0.921206  1.326825  2020-01-02  2021-09-14   299.266418
# 4221  HUBS   0.941002  1.275099  2020-01-02  2021-09-14   162.570007
# 120   ALGN   0.902588  1.298174  2020-01-02  2021-09-14   283.679993
# 3447   BLK   0.915144  1.208408  2020-01-02  2021-09-14   491.065094
# 3118  ZBRA   0.908919  0.966194  2020-01-02  2021-09-14   259.140015
# 5084    SE   0.963138  0.701782  2020-01-02  2021-09-14    40.040001
# 2757  TECH   0.917288  0.730570  2020-01-02  2021-09-14   217.998352
# 2247  POOL   0.910096  0.688281  2020-01-02  2021-09-14   211.169037
# 3680   CRL   0.926986  0.664332  2020-01-02  2021-09-14   153.889999
# 3753  DECK   0.911590  0.671050  2020-01-02  2021-09-14   172.169998
# 3136    ZS   0.906700  0.483915  2020-01-02  2021-09-14    47.330002
# 2466  SAIA   0.912870  0.439847  2020-01-02  2021-09-14    93.790001
# 2706  SWAV   0.905413  0.426589  2020-01-02  2021-09-14    44.230000
# 2042  ODFL   0.942130  0.374169  2020-01-02  2021-09-14   127.358101
# 4562   MOH   0.925378  0.332727  2020-01-02  2021-09-14   133.369995
# 2001  NVDA   0.903994  0.336886  2020-01-02  2021-09-14    59.844322
# 1872  MSFT   0.915964  0.308482  2020-01-02  2021-09-14   158.205765
# 2833  TSCO   0.903292  0.270841  2020-01-02  2021-09-14    91.421371
#
#         End_Price  Num_records  Num_records_2 Symbol  \
# 4592  1559.439941          423            423    MTD
# 5000   690.940002          423            423     RH
# 247    888.070007          429            429   ASML
# 4221   671.830017          423            423   HUBS
# 120    706.450012          429            429   ALGN
# 3447   901.950012          423            423    BLK
# 3118   576.789978          423            423   ZBRA
# 5084   333.549988          423            423     SE
# 2757   509.890015          423            423   TECH
# 2247   474.679993          423            423   POOL
# 3680   436.239990          423            423    CRL
# 3753   436.630005          423            423   DECK
# 3136   275.799988          424            424     ZS
# 2466   240.669998          424            424   SAIA
# 2706   220.139999          423            423   SWAV
# 2042   288.660004          424            424   ODFL
# 4562   262.049988          423            423    MOH
# 2001   222.419998          424            424   NVDA
# 1872   299.790009          424            424   MSFT
# 2833   205.259995          423            423   TSCO
#
#                                                    Name  \
# 4592     Mettler-Toledo International Inc. Common Stock
# 5000                                    RH Common Stock
# 247          ASML Holding N.V. New York Registry Shares
# 4221                          HubSpot Inc. Common Stock
# 120                  Align Technology Inc. Common Stock
# 3447                        BlackRock Inc. Common Stock
# 3118  Zebra Technologies Corporation Class A Common ...
# 5084  Sea Limited American Depositary Shares each re...
# 2757                       Bio-Techne Corp Common Stock
# 2247                      Pool Corporation Common Stock
# 3680  Charles River Laboratories International Inc. ...
# 3753           Deckers Outdoor Corporation Common Stock
# 3136                          Zscaler Inc. Common Stock
# 2466                             Saia Inc. Common Stock
# 2706                ShockWave Medical Inc. Common Stock
# 2042        Old Dominion Freight Line Inc. Common Stock
# 4562                 Molina Healthcare Inc Common Stock
# 2001                    NVIDIA Corporation Common Stock
# 1872                 Microsoft Corporation Common Stock
# 2833                Tractor Supply Company Common Stock
#
#                      Sector  \
# 4592            Health Care
# 5000      Consumer Services
# 247              Technology
# 4221             Technology
# 120             Health Care
# 3447                Finance
# 3118             Technology
# 5084             Technology
# 2757            Health Care
# 2247  Consumer Non-Durables
# 3680      Consumer Services
# 3753  Consumer Non-Durables
# 3136             Technology
# 2466         Transportation
# 2706            Health Care
# 2042         Transportation
# 4562            Health Care
# 2001             Technology
# 1872             Technology
# 2833      Consumer Services
#
#                                                Industry      SE   wt_Coef  \
# 4592                               Medical Specialities    NYSE  1.836325
# 5000                             Other Specialty Stores    NYSE  1.395834
# 247                     Industrial Machinery/Components  NASDAQ  1.222278
# 4221            Computer Software: Prepackaged Software    NYSE  1.199871
# 120                              Industrial Specialties  NASDAQ  1.171717
# 3447                 Investment Bankers/Brokers/Service    NYSE  1.105867
# 3118                      Computer peripheral equipment  NASDAQ  0.878192
# 5084            Computer Software: Prepackaged Software    NYSE  0.675913
# 2757  Biotechnology: Biological Products (No Diagnos...  NASDAQ  0.670143
# 2247                         Recreational Products/Toys  NASDAQ  0.626403
# 3680                                       EDP Services    NYSE  0.615827
# 3753                                 Shoe Manufacturing    NYSE  0.611722
# 3136                                       EDP Services  NASDAQ  0.438765
# 2466                  Trucking Freight/Courier Services  NASDAQ  0.401523
# 2706                         Medical/Dental Instruments  NASDAQ  0.386240
# 2042                  Trucking Freight/Courier Services  NASDAQ  0.352516
# 4562                               Medical Specialities    NYSE  0.307898
# 2001                                     Semiconductors  NASDAQ  0.304543
# 1872            Computer Software: Prepackaged Software  NASDAQ  0.282558
# 2833                             Other Specialty Stores  NASDAQ  0.244648
#
#       last_3m_avg_PCT_CHANGE
# 4592                0.001879
# 5000                0.000459
# 247                 0.004847
# 4221                0.005242
# 120                 0.000388
# 3447                0.001307
# 3118                0.001730
# 5084                0.004290
# 2757                0.002485
# 2247                0.000984
# 3680                0.003267
# 3753                0.002609
# 3136                0.005541
# 2466                0.005591
# 2706                0.008248
# 2042                0.003746
# 4562                0.000379
# 2001                0.004956
# 1872                0.001251
# 2833                0.003089

# %%
## Viz
df_temp=df_2.loc[df_2.Stock.isin(['ASML','ODFL']),:].melt(id_vars=['Date','SE','Stock'],
                                                                value_vars=['Close','Close_m30_avg'],
                                                                var_name='type',
                                                                value_name='vals'
                                                               ) #'IDXX','CRWD','TGT'
print(
    ggplot(df_temp,aes('Date','vals',color='type'))
    +geom_line()
    +scale_x_datetime(date_breaks='14 day', date_labels='%Y-%m')
    +facet_grid('Stock~.',scales='free_y')
    +theme(axis_text_x=element_text(angle=90),figure_size=(12,8))
)
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8743195471149)>
